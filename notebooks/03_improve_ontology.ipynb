# %%
import sys
sys.path.append("..")

# %matplotlib inline
# %load_ext autoreload
# %autoreload 1
# %aimport pyfantom.network_tools

from orangecontrib.bio.ontology import OBOOntology, OBOObject
import networkx as nx
from pylab import * 
from itertools import repeat
import pandas as pd
import re
from pprint import pprint

from pyfantom.network_tools import *
pd.set_option('display.max_colwidth', -1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Improving the Ontology Network
#
# Based on our finding in `explore_ontology.ipynb`, this notebook deals with improving the network built from the ontology.
# In particular, we will
# * Add the missing entries
# * deal with the singletons
#
# Load Ontology and Annotation:

# %%
obo = OBOOntology()
obo.load(open("../data/ff-phase2-140729.obo"))
## Obo instance to which we will write the corrections
obo_corr = OBOOntology()
obo_corr.load(open("../data/ff-phase2-140729.obo"))
col_vars = pd.read_csv("../data/column_vars.processed.csv", index_col=0)

# %% [markdown]
# Define ontology constants:

# %%
UPDATE = "correction_gs01"
HUMAN_SAMPLE = ("FF:0000210", None, "human sample")
IS_A = "is_a"
RELATIONSHIP = "relationship"
SUBSET = "subset"

# %% [markdown]
# ## Add the missing entries
# (they will show up as singletons in the next step to add them to their corresponding group)

# %%
missing_samples = !cat ../data/missing_samples.txt
missing_sample_ids = [x.split()[0][:-1] for x in missing_samples]

# %%
for obo_id in missing_sample_ids:
    term = obo_corr.term(obo_id)
    term.add_tag(SUBSET, UPDATE)
    term.add_tag(IS_A, *HUMAN_SAMPLE)

# %%
obo_corr.write(open("../data/tmp/ff-phase2-140729.corr.2.obo", 'w'))

# %% [markdown]
# ## Inspect Singletons
# What is a singleton?
#
# Every sample (FF:#####-#####) that is a direct descendant of human sample appears in the network as a singleton.
#
# Get these samples:

# %%
singletons_df = col_vars[col_vars.obo_id.isin([term.id for term in obo_corr.child_terms(HUMAN_SAMPLE[0])])]

# %%
len(singletons_df)
# Out:
# 568

# %% [markdown]
# #### Most of the singletons do actually have a superclass
# These superclasses are just not associated with 'human sample', thus, these classes appear as singleton in the network

# %%
for i, obo_id in enumerate(singletons_df.obo_id.values): 
    for tag, value, _ , comment in obo.term(obo_id).tags(): 
        if tag == IS_A: 
            print(i, tag, value, comment)
# Out:
# 0 is_a FF:0000210 human sample
# 0 is_a FF:0000357 0 hr sample
# 0 is_a FF:0200008 293SLAM rinderpest infection sample
# 1 is_a FF:0000210 human sample
# 1 is_a FF:0000357 0 hr sample
# 1 is_a FF:0200008 293SLAM rinderpest infection sample
# 2 is_a FF:0000210 human sample
# 2 is_a FF:0000357 0 hr sample
# 2 is_a FF:0200008 293SLAM rinderpest infection sample
# 3 is_a FF:0000210 human sample
# 3 is_a FF:0000363 6 hr sample
# 3 is_a FF:0200008 293SLAM rinderpest infection sample
# 4 is_a FF:0000210 human sample
# 4 is_a FF:0000363 6 hr sample
# 4 is_a FF:0200008 293SLAM rinderpest infection sample
# 5 is_a FF:0000210 human sample
# 5 is_a FF:0000363 6 hr sample
# 5 is_a FF:0200008 293SLAM rinderpest infection sample
# 6 is_a FF:0000210 human sample
# 6 is_a FF:0000367 12 hr sample
# 6 is_a FF:0200008 293SLAM rinderpest infection sample
# 7 is_a FF:0000210 human sample
# 7 is_a FF:0000367 12 hr sample
# 7 is_a FF:0200008 293SLAM rinderpest infection sample
# 8 is_a FF:0000210 human sample
# 8 is_a FF:0000367 12 hr sample
# 8 is_a FF:0200008 293SLAM rinderpest infection sample
# 9 is_a FF:0000210 human sample
# 9 is_a FF:0000373 24 hr sample
# 9 is_a FF:0200008 293SLAM rinderpest infection sample
# 10 is_a FF:0000210 human sample
# 10 is_a FF:0000373 24 hr sample
# 10 is_a FF:0200008 293SLAM rinderpest infection sample
# 11 is_a FF:0000210 human sample
# 11 is_a FF:0000373 24 hr sample
# 11 is_a FF:0200008 293SLAM rinderpest infection sample
# 12 is_a FF:0000210 human sample
# 12 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 13 is_a FF:0000210 human sample
# 13 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 14 is_a FF:0000210 human sample
# 14 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 15 is_a FF:0000210 human sample
# 15 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 16 is_a FF:0000210 human sample
# 16 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 17 is_a FF:0000210 human sample
# 17 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 18 is_a FF:0000210 human sample
# 18 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 19 is_a FF:0000210 human sample
# 19 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 20 is_a FF:0000210 human sample
# 20 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 21 is_a FF:0000210 human sample
# 21 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 22 is_a FF:0000210 human sample
# 22 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 23 is_a FF:0000210 human sample
# 23 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 24 is_a FF:0000210 human sample
# 24 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 25 is_a FF:0000210 human sample
# 25 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 26 is_a FF:0000210 human sample
# 26 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 27 is_a FF:0000210 human sample
# 27 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 28 is_a FF:0000210 human sample
# 28 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 29 is_a FF:0000210 human sample
# 29 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 30 is_a FF:0000210 human sample
# 30 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 31 is_a FF:0000210 human sample
# 31 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 32 is_a FF:0000210 human sample
# 32 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 33 is_a FF:0000210 human sample
# 33 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 34 is_a FF:0000210 human sample
# 34 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 35 is_a FF:0000210 human sample
# 35 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 36 is_a FF:0000210 human sample
# 36 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 37 is_a FF:0000210 human sample
# 37 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 38 is_a FF:0000210 human sample
# 38 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 39 is_a FF:0000210 human sample
# 39 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 40 is_a FF:0000210 human sample
# 40 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 41 is_a FF:0000210 human sample
# 41 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 42 is_a FF:0000210 human sample
# 42 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 43 is_a FF:0000210 human sample
# 43 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 44 is_a FF:0000210 human sample
# 44 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 45 is_a FF:0000210 human sample
# 45 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 46 is_a FF:0000210 human sample
# 46 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 47 is_a FF:0000210 human sample
# 47 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 48 is_a FF:0000210 human sample
# 48 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 49 is_a FF:0000210 human sample
# 49 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 50 is_a FF:0000210 human sample
# 50 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 51 is_a FF:0000210 human sample
# 51 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 52 is_a FF:0000210 human sample
# 52 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 53 is_a FF:0000210 human sample
# 53 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 54 is_a FF:0000210 human sample
# 54 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 55 is_a FF:0000210 human sample
# 55 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 56 is_a FF:0000210 human sample
# 56 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 57 is_a FF:0000210 human sample
# 57 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 58 is_a FF:0000210 human sample
# 58 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 59 is_a FF:0000210 human sample
# 59 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 60 is_a FF:0000210 human sample
# 60 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 61 is_a FF:0000210 human sample
# 61 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 62 is_a FF:0000210 human sample
# 62 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 63 is_a FF:0000210 human sample
# 63 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 64 is_a FF:0000210 human sample
# 64 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 65 is_a FF:0000210 human sample
# 65 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 66 is_a FF:0000210 human sample
# 66 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 67 is_a FF:0000210 human sample
# 67 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 68 is_a FF:0000210 human sample
# 68 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 69 is_a FF:0000210 human sample
# 69 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 70 is_a FF:0000210 human sample
# 70 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 71 is_a FF:0000210 human sample
# 71 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 72 is_a FF:0000210 human sample
# 72 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 73 is_a FF:0000210 human sample
# 73 is_a FF:0300100 ARPE-19 EMT induced with TGF-beta and TNF-alpha sample
# 74 is_a EFO:0002091 biological replicate
# 74 is_a FF:0000210 human sample
# 74 is_a FF:0102062 B-lymphoblastoid cell line sample
# 75 is_a EFO:0002091 biological replicate
# 75 is_a FF:0000210 human sample
# 75 is_a FF:0102062 B-lymphoblastoid cell line sample
# 76 is_a EFO:0002091 biological replicate
# 76 is_a FF:0000210 human sample
# 76 is_a FF:0102062 B-lymphoblastoid cell line sample
# 77 is_a EFO:0002091 biological replicate
# 77 is_a FF:0000210 human sample
# 77 is_a FF:0101561 DAUDI cell sample
# 78 is_a EFO:0002091 biological replicate
# 78 is_a FF:0000210 human sample
# 78 is_a FF:0101154 RAJI cell sample
# 79 is_a EFO:0002091 biological replicate
# 79 is_a FF:0000025 CD19-positive B cell sample
# 79 is_a FF:0000210 human sample
# 80 is_a EFO:0002091 biological replicate
# 80 is_a FF:0000025 CD19-positive B cell sample
# 80 is_a FF:0000210 human sample
# 81 is_a EFO:0002091 biological replicate
# 81 is_a FF:0000025 CD19-positive B cell sample
# 81 is_a FF:0000210 human sample
# 82 is_a EFO:0002091 biological replicate
# 82 is_a FF:0000025 CD19-positive B cell sample
# 82 is_a FF:0000210 human sample
# 83 is_a EFO:0002091 biological replicate
# 83 is_a FF:0000025 CD19-positive B cell sample
# 83 is_a FF:0000210 human sample
# 84 is_a EFO:0002091 biological replicate
# 84 is_a FF:0000025 CD19-positive B cell sample
# 84 is_a FF:0000210 human sample
# 85 is_a EFO:0002091 biological replicate
# 85 is_a FF:0000025 CD19-positive B cell sample
# 85 is_a FF:0000210 human sample
# 86 is_a EFO:0002091 biological replicate
# 86 is_a FF:0000025 CD19-positive B cell sample
# 86 is_a FF:0000210 human sample
# 87 is_a EFO:0002091 biological replicate
# 87 is_a FF:0000025 CD19-positive B cell sample
# 87 is_a FF:0000210 human sample
# 88 is_a EFO:0002091 biological replicate
# 88 is_a FF:0000025 CD19-positive B cell sample
# 88 is_a FF:0000210 human sample
# 89 is_a EFO:0002091 biological replicate
# 89 is_a FF:0000025 CD19-positive B cell sample
# 89 is_a FF:0000210 human sample
# 90 is_a EFO:0002091 biological replicate
# 90 is_a FF:0000031 CD4-positive T cell sample
# 90 is_a FF:0000210 human sample
# 91 is_a EFO:0002091 biological replicate
# 91 is_a FF:0000031 CD4-positive T cell sample
# 91 is_a FF:0000210 human sample
# 92 is_a EFO:0002091 biological replicate
# 92 is_a FF:0000031 CD4-positive T cell sample
# 92 is_a FF:0000210 human sample
# 93 is_a EFO:0002091 biological replicate
# 93 is_a FF:0000002 in vivo cell sample
# 93 is_a FF:0000210 human sample
# 94 is_a EFO:0002091 biological replicate
# 95 is_a EFO:0002091 biological replicate
# 96 is_a EFO:0002091 biological replicate
# 96 is_a FF:0000002 in vivo cell sample
# 96 is_a FF:0000210 human sample
# 97 is_a EFO:0002091 biological replicate
# 97 is_a FF:0000002 in vivo cell sample
# 97 is_a FF:0000210 human sample
# 98 is_a EFO:0002091 biological replicate
# 98 is_a FF:0000002 in vivo cell sample
# 98 is_a FF:0000210 human sample
# 99 is_a EFO:0002091 biological replicate
# 99 is_a FF:0000002 in vivo cell sample
# 99 is_a FF:0000210 human sample
# 100 is_a EFO:0002091 biological replicate
# 100 is_a FF:0000002 in vivo cell sample
# 100 is_a FF:0000210 human sample
# 101 is_a EFO:0002091 biological replicate
# 101 is_a FF:0000002 in vivo cell sample
# 101 is_a FF:0000210 human sample
# 102 is_a EFO:0002091 biological replicate
# 102 is_a FF:0000002 in vivo cell sample
# 102 is_a FF:0000210 human sample
# 103 is_a EFO:0002091 biological replicate
# 103 is_a FF:0000002 in vivo cell sample
# 103 is_a FF:0000210 human sample
# 104 is_a EFO:0002091 biological replicate
# 104 is_a FF:0000002 in vivo cell sample
# 104 is_a FF:0000210 human sample
# 105 is_a EFO:0002091 biological replicate
# 105 is_a FF:0000002 in vivo cell sample
# 105 is_a FF:0000210 human sample
# 106 is_a EFO:0002091 biological replicate
# 106 is_a FF:0000002 in vivo cell sample
# 106 is_a FF:0000210 human sample
# 107 is_a EFO:0002091 biological replicate
# 107 is_a FF:0000002 in vivo cell sample
# 107 is_a FF:0000210 human sample
# 108 is_a EFO:0002091 biological replicate
# 108 is_a FF:0000002 in vivo cell sample
# 108 is_a FF:0000210 human sample
# 109 is_a EFO:0002091 biological replicate
# 109 is_a FF:0000002 in vivo cell sample
# 109 is_a FF:0000210 human sample
# 110 is_a EFO:0002091 biological replicate
# 111 is_a EFO:0002091 biological replicate
# 112 is_a EFO:0002091 biological replicate
# 112 is_a FF:0000002 in vivo cell sample
# 112 is_a FF:0000210 human sample
# 113 is_a EFO:0002091 biological replicate
# 113 is_a FF:0000002 in vivo cell sample
# 113 is_a FF:0000210 human sample
# 114 is_a EFO:0002091 biological replicate
# 114 is_a FF:0000030 CD8-positive T cell sample
# 114 is_a FF:0000210 human sample
# 115 is_a EFO:0002091 biological replicate
# 115 is_a FF:0000030 CD8-positive T cell sample
# 115 is_a FF:0000210 human sample
# 116 is_a EFO:0002091 biological replicate
# 116 is_a FF:0000030 CD8-positive T cell sample
# 116 is_a FF:0000210 human sample
# 117 is_a EFO:0002091 biological replicate
# 117 is_a FF:0000030 CD8-positive T cell sample
# 117 is_a FF:0000210 human sample
# 118 is_a EFO:0002091 biological replicate
# 118 is_a FF:0000030 CD8-positive T cell sample
# 118 is_a FF:0000210 human sample
# 119 is_a EFO:0002091 biological replicate
# 119 is_a FF:0000030 CD8-positive T cell sample
# 119 is_a FF:0000210 human sample
# 120 is_a EFO:0002091 biological replicate
# 120 is_a FF:0000030 CD8-positive T cell sample
# 120 is_a FF:0000210 human sample
# 121 is_a EFO:0002091 biological replicate
# 121 is_a FF:0000030 CD8-positive T cell sample
# 121 is_a FF:0000210 human sample
# 122 is_a EFO:0002091 biological replicate
# 122 is_a FF:0000030 CD8-positive T cell sample
# 122 is_a FF:0000210 human sample
# 123 is_a EFO:0002091 biological replicate
# 123 is_a FF:0000030 CD8-positive T cell sample
# 123 is_a FF:0000210 human sample
# 124 is_a EFO:0002091 biological replicate
# 124 is_a FF:0000030 CD8-positive T cell sample
# 124 is_a FF:0000210 human sample
# 125 is_a FF:0000210 human sample
# 125 is_a FF:0000357 0 hr sample
# 125 is_a FF:0200009 COBL-a rinderpest infection sample
# 126 is_a FF:0000210 human sample
# 126 is_a FF:0000357 0 hr sample
# 126 is_a FF:0200009 COBL-a rinderpest infection sample
# 127 is_a FF:0000210 human sample
# 127 is_a FF:0000357 0 hr sample
# 127 is_a FF:0200009 COBL-a rinderpest infection sample
# 128 is_a FF:0000210 human sample
# 128 is_a FF:0000363 6 hr sample
# 128 is_a FF:0200009 COBL-a rinderpest infection sample
# 129 is_a FF:0000210 human sample
# 129 is_a FF:0000363 6 hr sample
# 129 is_a FF:0200009 COBL-a rinderpest infection sample
# 130 is_a FF:0000210 human sample
# 130 is_a FF:0000363 6 hr sample
# 130 is_a FF:0200009 COBL-a rinderpest infection sample
# 131 is_a FF:0000210 human sample
# 131 is_a FF:0000367 12 hr sample
# 131 is_a FF:0200009 COBL-a rinderpest infection sample
# 132 is_a FF:0000210 human sample
# 132 is_a FF:0000367 12 hr sample
# 132 is_a FF:0200009 COBL-a rinderpest infection sample
# 133 is_a FF:0000210 human sample
# 133 is_a FF:0000367 12 hr sample
# 133 is_a FF:0200009 COBL-a rinderpest infection sample
# 134 is_a FF:0000210 human sample
# 134 is_a FF:0000373 24 hr sample
# 134 is_a FF:0200009 COBL-a rinderpest infection sample
# 135 is_a FF:0000210 human sample
# 135 is_a FF:0000373 24 hr sample
# 135 is_a FF:0200009 COBL-a rinderpest infection sample
# 136 is_a FF:0000210 human sample
# 136 is_a FF:0000373 24 hr sample
# 136 is_a FF:0200009 COBL-a rinderpest infection sample
# 137 is_a FF:0000210 human sample
# 137 is_a FF:0000375 48 hr sample
# 137 is_a FF:0200009 COBL-a rinderpest infection sample
# 138 is_a FF:0000210 human sample
# 138 is_a FF:0000375 48 hr sample
# 138 is_a FF:0200009 COBL-a rinderpest infection sample
# 139 is_a FF:0000210 human sample
# 139 is_a FF:0000375 48 hr sample
# 139 is_a FF:0200009 COBL-a rinderpest infection sample
# 140 is_a FF:0000210 human sample
# 140 is_a FF:0000363 6 hr sample
# 140 is_a FF:0200009 COBL-a rinderpest infection sample
# 141 is_a FF:0000210 human sample
# 141 is_a FF:0000363 6 hr sample
# 141 is_a FF:0200009 COBL-a rinderpest infection sample
# 142 is_a FF:0000210 human sample
# 142 is_a FF:0000363 6 hr sample
# 142 is_a FF:0200009 COBL-a rinderpest infection sample
# 143 is_a FF:0000210 human sample
# 143 is_a FF:0000367 12 hr sample
# 143 is_a FF:0200009 COBL-a rinderpest infection sample
# 144 is_a FF:0000210 human sample
# 144 is_a FF:0000367 12 hr sample
# 144 is_a FF:0200009 COBL-a rinderpest infection sample
# 145 is_a FF:0000210 human sample
# 145 is_a FF:0000367 12 hr sample
# 145 is_a FF:0200009 COBL-a rinderpest infection sample
# 146 is_a FF:0000210 human sample
# 146 is_a FF:0000373 24 hr sample
# 146 is_a FF:0200009 COBL-a rinderpest infection sample
# 147 is_a FF:0000210 human sample
# 147 is_a FF:0000373 24 hr sample
# 147 is_a FF:0200009 COBL-a rinderpest infection sample
# 148 is_a FF:0000210 human sample
# 148 is_a FF:0000373 24 hr sample
# 148 is_a FF:0200009 COBL-a rinderpest infection sample
# 149 is_a FF:0000210 human sample
# 149 is_a FF:0000375 48 hr sample
# 149 is_a FF:0200009 COBL-a rinderpest infection sample
# 150 is_a FF:0000210 human sample
# 150 is_a FF:0000375 48 hr sample
# 150 is_a FF:0200009 COBL-a rinderpest infection sample
# 151 is_a FF:0000210 human sample
# 151 is_a FF:0000375 48 hr sample
# 151 is_a FF:0200009 COBL-a rinderpest infection sample
# 152 is_a FF:0000004 tissue sample
# 152 is_a FF:0000210 human sample
# 153 is_a EFO:0002091 biological replicate
# 153 is_a FF:0000210 human sample
# 153 is_a FF:0104201 Ewing's sarcoma cell line sample
# 154 is_a EFO:0002091 biological replicate
# 155 is_a EFO:0002091 biological replicate
# 156 is_a EFO:0002091 biological replicate
# 156 is_a FF:0000210 human sample
# 157 is_a EFO:0002091 biological replicate
# 157 is_a FF:0000077 hepatic stellate cell sample
# 157 is_a FF:0000210 human sample
# 158 is_a EFO:0002091 biological replicate
# 158 is_a FF:0000077 hepatic stellate cell sample
# 158 is_a FF:0000210 human sample
# 159 is_a EFO:0002091 biological replicate
# 159 is_a FF:0000077 hepatic stellate cell sample
# 159 is_a FF:0000210 human sample
# 160 is_a EFO:0002091 biological replicate
# 160 is_a FF:0000210 human sample
# 160 is_a FF:0104973 Hodgkin lymphoma cell line sample
# 161 is_a EFO:0002091 biological replicate
# 161 is_a FF:0000003 cell line sample
# 161 is_a FF:0000210 human sample
# 162 is_a EFO:0002091 biological replicate
# 162 is_a FF:0000210 human sample
# 162 is_a FF:0000262 mast cell- stimulated sample
# 163 is_a EFO:0002091 biological replicate
# 163 is_a FF:0000210 human sample
# 163 is_a FF:0000261 mast cell- heparinase treated sample
# 164 is_a EFO:0002091 biological replicate
# 164 is_a FF:0000210 human sample
# 164 is_a FF:0000261 mast cell- heparinase treated sample
# 165 is_a EFO:0002091 biological replicate
# 165 is_a FF:0000210 human sample
# 165 is_a FF:0000261 mast cell- heparinase treated sample
# 166 is_a EFO:0002091 biological replicate
# 166 is_a FF:0000210 human sample
# 166 is_a FF:0000261 mast cell- heparinase treated sample
# 167 is_a FF:0000262 mast cell- stimulated sample
# 168 is_a FF:0000260 mast cell sample
# 169 is_a FF:0000260 mast cell sample
# 170 is_a FF:0000260 mast cell sample
# 171 is_a FF:0000210 human sample
# 171 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 172 is_a FF:0000210 human sample
# 172 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 173 is_a FF:0000210 human sample
# 173 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 174 is_a FF:0000210 human sample
# 174 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 175 is_a FF:0000210 human sample
# 175 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 176 is_a FF:0000210 human sample
# 176 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 177 is_a FF:0000210 human sample
# 177 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 178 is_a FF:0000210 human sample
# 178 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 179 is_a FF:0000210 human sample
# 179 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 180 is_a FF:0000210 human sample
# 180 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 181 is_a FF:0000210 human sample
# 181 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 182 is_a FF:0000210 human sample
# 182 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 183 is_a FF:0000210 human sample
# 183 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 184 is_a FF:0000210 human sample
# 184 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 185 is_a FF:0000210 human sample
# 185 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 186 is_a FF:0000210 human sample
# 186 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 187 is_a FF:0000210 human sample
# 187 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 188 is_a FF:0000210 human sample
# 188 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 189 is_a FF:0000210 human sample
# 189 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 190 is_a FF:0000210 human sample
# 190 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 191 is_a FF:0000210 human sample
# 191 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 192 is_a FF:0000210 human sample
# 192 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 193 is_a FF:0000210 human sample
# 193 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 194 is_a FF:0000210 human sample
# 194 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 195 is_a FF:0000210 human sample
# 195 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 196 is_a FF:0000210 human sample
# 196 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 197 is_a FF:0000210 human sample
# 197 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 198 is_a FF:0000210 human sample
# 198 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 199 is_a FF:0000210 human sample
# 199 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 200 is_a FF:0000210 human sample
# 200 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 201 is_a FF:0000210 human sample
# 201 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 202 is_a FF:0000210 human sample
# 202 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 203 is_a FF:0000210 human sample
# 203 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 204 is_a FF:0000210 human sample
# 204 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 205 is_a FF:0000210 human sample
# 205 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 206 is_a FF:0000210 human sample
# 206 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 207 is_a FF:0000210 human sample
# 207 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 208 is_a FF:0000210 human sample
# 208 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 209 is_a FF:0000210 human sample
# 209 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 210 is_a FF:0000210 human sample
# 210 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 211 is_a FF:0000210 human sample
# 211 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 212 is_a FF:0000210 human sample
# 212 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 213 is_a FF:0000210 human sample
# 213 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 214 is_a FF:0000210 human sample
# 214 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 215 is_a FF:0000210 human sample
# 215 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 216 is_a FF:0000210 human sample
# 216 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 217 is_a FF:0000210 human sample
# 217 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 218 is_a FF:0000210 human sample
# 218 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 219 is_a FF:0000210 human sample
# 219 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 220 is_a FF:0000210 human sample
# 220 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 221 is_a FF:0000210 human sample
# 221 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 222 is_a FF:0000210 human sample
# 222 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 223 is_a FF:0000210 human sample
# 223 is_a FF:0200006 myoblast differentiation to myotubes, control sample
# 224 is_a EFO:0002091 biological replicate
# 224 is_a FF:0000210 human sample
# 224 is_a FF:0102504 T-lymphoblastic leukemia cell line sample
# 225 is_a FF:0000004 tissue sample
# 225 is_a FF:0000210 human sample
# 226 is_a FF:0000002 in vivo cell sample
# 226 is_a FF:0000210 human sample
# 227 is_a FF:0000002 in vivo cell sample
# 227 is_a FF:0000210 human sample
# 228 is_a FF:0000002 in vivo cell sample
# 228 is_a FF:0000210 human sample
# 229 is_a FF:0000002 in vivo cell sample
# 229 is_a FF:0000210 human sample
# 230 is_a FF:0000002 in vivo cell sample
# 230 is_a FF:0000210 human sample
# 231 is_a FF:0000002 in vivo cell sample
# 231 is_a FF:0000210 human sample
# 232 is_a EFO:0001461 control
# 232 is_a FF:0000002 in vivo cell sample
# 232 is_a FF:0000210 human sample
# 233 is_a EFO:0001461 control
# 233 is_a FF:0000002 in vivo cell sample
# 233 is_a FF:0000210 human sample
# 234 is_a EFO:0001461 control
# 234 is_a FF:0000002 in vivo cell sample
# 234 is_a FF:0000210 human sample
# 235 is_a EFO:0001461 control
# 235 is_a FF:0000002 in vivo cell sample
# 235 is_a FF:0000210 human sample
# 236 is_a FF:0000004 tissue sample
# 236 is_a FF:0000210 human sample
# 237 is_a EFO:0002091 biological replicate
# 237 is_a FF:0000210 human sample
# 237 is_a FF:0102586 G-401 cell sample
# 238 is_a EFO:0002091 biological replicate
# 238 is_a FF:0000210 human sample
# 238 is_a FF:0103192 renal cancer cell line sample
# 239 is_a EFO:0002091 biological replicate
# 239 is_a FF:0000210 human sample
# 239 is_a FF:0102024 squamous cell carcinoma cell line sample
# 240 is_a EFO:0002091 biological replicate
# 240 is_a FF:0000210 human sample
# 240 is_a FF:0102144 acute lymphoblastic leukemia cell line sample
# 241 is_a EFO:0002091 biological replicate
# 241 is_a FF:0000210 human sample
# 241 is_a FF:0103288 NALM-6 cell sample
# 242 is_a EFO:0002091 biological replicate
# 242 is_a FF:0000210 human sample
# 242 is_a FF:0101952 HPB-ALL cell sample
# 243 is_a EFO:0002091 biological replicate
# 243 is_a FF:0000210 human sample
# 243 is_a FF:0100661 JURKAT cell sample
# 244 is_a EFO:0002091 biological replicate
# 244 is_a FF:0000210 human sample
# 244 is_a FF:0101883 acute myeloid leukemia cell line sample
# 245 is_a EFO:0002091 biological replicate
# 245 is_a FF:0000210 human sample
# 245 is_a FF:0101883 acute myeloid leukemia cell line sample
# 246 is_a EFO:0002091 biological replicate
# 246 is_a FF:0000210 human sample
# 246 is_a FF:0101883 acute myeloid leukemia cell line sample
# 247 is_a EFO:0002091 biological replicate
# 247 is_a FF:0000210 human sample
# 247 is_a FF:0101883 acute myeloid leukemia cell line sample
# 248 is_a EFO:0002091 biological replicate
# 248 is_a FF:0000210 human sample
# 248 is_a FF:0101883 acute myeloid leukemia cell line sample
# 249 is_a EFO:0002091 biological replicate
# 249 is_a FF:0000210 human sample
# 249 is_a FF:0101883 acute myeloid leukemia cell line sample
# 250 is_a EFO:0002091 biological replicate
# 250 is_a FF:0000210 human sample
# 250 is_a FF:0101883 acute myeloid leukemia cell line sample
# 251 is_a EFO:0002091 biological replicate
# 251 is_a FF:0000210 human sample
# 251 is_a FF:0101883 acute myeloid leukemia cell line sample
# 252 is_a EFO:0002091 biological replicate
# 252 is_a FF:0000210 human sample
# 252 is_a FF:0101883 acute myeloid leukemia cell line sample
# 253 is_a EFO:0002091 biological replicate
# 253 is_a FF:0000210 human sample
# 253 is_a FF:0101883 acute myeloid leukemia cell line sample
# 254 is_a EFO:0002091 biological replicate
# 254 is_a FF:0000210 human sample
# 254 is_a FF:0101883 acute myeloid leukemia cell line sample
# 255 is_a EFO:0002091 biological replicate
# 255 is_a FF:0000210 human sample
# 255 is_a FF:0101883 acute myeloid leukemia cell line sample
# 256 is_a EFO:0002091 biological replicate
# 256 is_a FF:0000210 human sample
# 256 is_a FF:0101883 acute myeloid leukemia cell line sample
# 257 is_a EFO:0002091 biological replicate
# 257 is_a FF:0000210 human sample
# 257 is_a FF:0000661 acute myeloid leukemia (FAB M5) cell line:THP-1 cytoplasmic fraction sample
# 258 is_a EFO:0002091 biological replicate
# 258 is_a FF:0000210 human sample
# 258 is_a FF:0101370 THP-1 cell sample
# 258 is_a FF:0101883 acute myeloid leukemia cell line sample
# 259 is_a EFO:0002091 biological replicate
# 259 is_a FF:0000210 human sample
# 259 is_a FF:0101370 THP-1 cell sample
# 259 is_a FF:0101883 acute myeloid leukemia cell line sample
# 260 is_a EFO:0002091 biological replicate
# 260 is_a FF:0000210 human sample
# 260 is_a FF:0101370 THP-1 cell sample
# 260 is_a FF:0101883 acute myeloid leukemia cell line sample
# 261 is_a EFO:0002091 biological replicate
# 261 is_a FF:0000210 human sample
# 261 is_a FF:0101883 acute myeloid leukemia cell line sample
# 262 is_a EFO:0002091 biological replicate
# 262 is_a FF:0000210 human sample
# 262 is_a FF:0101883 acute myeloid leukemia cell line sample
# 263 is_a EFO:0002091 biological replicate
# 263 is_a FF:0000210 human sample
# 263 is_a FF:0101883 acute myeloid leukemia cell line sample
# 264 is_a EFO:0002091 biological replicate
# 264 is_a FF:0000210 human sample
# 264 is_a FF:0101883 acute myeloid leukemia cell line sample
# 265 is_a EFO:0002091 biological replicate
# 265 is_a FF:0000210 human sample
# 265 is_a FF:0101883 acute myeloid leukemia cell line sample
# 266 is_a EFO:0002091 biological replicate
# 266 is_a FF:0000210 human sample
# 266 is_a FF:0101883 acute myeloid leukemia cell line sample
# 267 is_a EFO:0002091 biological replicate
# 267 is_a FF:0000210 human sample
# 267 is_a FF:0100167 adenocarcinoma cell line sample
# 268 is_a EFO:0002091 biological replicate
# 268 is_a FF:0000210 human sample
# 268 is_a FF:0100167 adenocarcinoma cell line sample
# 269 is_a EFO:0002091 biological replicate
# 269 is_a FF:0000210 human sample
# 269 is_a FF:0104049 adult T-cell lymphoma cell line sample
# 270 is_a EFO:0002091 biological replicate
# 270 is_a FF:0000210 human sample
# 270 is_a FF:0102060 bronchioalveolar carcinoma cell sample
# 270 is_a FF:0104802 bronchioloalveolar carcinoma cell sample
# 271 is_a FF:0000004 tissue sample
# 271 is_a FF:0000210 human sample
# 272 is_a EFO:0002091 biological replicate
# 272 is_a FF:0000210 human sample
# 272 is_a FF:0100919 8305C cell sample
# 273 is_a EFO:0002091 biological replicate
# 273 is_a FF:0000210 human sample
# 273 is_a FF:0103212 T-lymphoma cell line sample
# 273 is_a FF:0104868 anaplastic large cell lymphoma cell line sample
# 274 is_a EFO:0002091 biological replicate
# 274 is_a FF:0000210 human sample
# 274 is_a FF:0104205 RPMI-2650 cell sample
# 275 is_a EFO:0002091 biological replicate
# 275 is_a FF:0000210 human sample
# 275 is_a FF:0100297 carcinoma cell line sample
# 275 is_a FF:0101967 cervical cancer cell line sample
# 276 is_a EFO:0002091 biological replicate
# 276 is_a FF:0000210 human sample
# 276 is_a FF:0100101 astrocytoma cell line sample
# 277 is_a EFO:0002091 biological replicate
# 277 is_a FF:0000210 human sample
# 277 is_a FF:0101522 B-lymphocyte cell line sample
# 278 is_a EFO:0002091 biological replicate
# 278 is_a FF:0000210 human sample
# 278 is_a FF:0100297 carcinoma cell line sample
# 279 is_a EFO:0002091 biological replicate
# 279 is_a FF:0000210 human sample
# 279 is_a FF:0100297 carcinoma cell line sample
# 279 is_a FF:0103911 HuCCT-1 cell sample
# 280 is_a EFO:0002091 biological replicate
# 280 is_a FF:0000210 human sample
# 280 is_a FF:0100297 carcinoma cell line sample
# 280 is_a FF:0103910 bile duct cancer cell line sample
# 281 is_a EFO:0002091 biological replicate
# 281 is_a FF:0000210 human sample
# 281 is_a FF:0100740 myeloid leukemia cell line sample
# 281 is_a FF:0100741 lymphocytic leukemia cell line sample
# 282 is_a EFO:0002091 biological replicate
# 282 is_a FF:0000210 human sample
# 282 is_a FF:0103296 bone marrow stromal cell line sample
# 283 is_a EFO:0002091 biological replicate
# 283 is_a FF:0000210 human sample
# 283 is_a FF:0100093 MCF-7 cell sample
# 284 is_a EFO:0002091 biological replicate
# 284 is_a FF:0000210 human sample
# 284 is_a FF:0101908 MDA-MB-453 cell sample
# 285 is_a EFO:0002091 biological replicate
# 285 is_a FF:0000210 human sample
# 285 is_a FF:0102024 squamous cell carcinoma cell line sample
# 286 is_a EFO:0002091 biological replicate
# 286 is_a FF:0000210 human sample
# 286 is_a FF:0102060 bronchioalveolar carcinoma cell sample
# 286 is_a FF:0102835 NCI-H358 cell sample
# 286 is_a FF:0104802 bronchioloalveolar carcinoma cell sample
# 287 is_a EFO:0002091 biological replicate
# 287 is_a FF:0000210 human sample
# 287 is_a FF:0102060 bronchioalveolar carcinoma cell sample
# 287 is_a FF:0104079 H-650 cell sample
# 287 is_a FF:0104802 bronchioloalveolar carcinoma cell sample
# 288 is_a EFO:0002091 biological replicate
# 288 is_a FF:0000210 human sample
# 288 is_a FF:0102061 bronchogenic carcinoma cell sample
# 289 is_a EFO:0002091 biological replicate
# 289 is_a FF:0000210 human sample
# 289 is_a FF:0100729 carcinoid cell sample
# 289 is_a FF:0103764 NCI cell sample
# 290 is_a EFO:0002091 biological replicate
# 290 is_a FF:0000210 human sample
# 290 is_a FF:0100729 carcinoid cell sample
# 290 is_a FF:0103764 NCI cell sample
# 291 is_a EFO:0002091 biological replicate
# 291 is_a FF:0000210 human sample
# 291 is_a FF:0100729 carcinoid cell sample
# 292 is_a EFO:0002091 biological replicate
# 292 is_a FF:0000210 human sample
# 292 is_a FF:0100197 carcinosarcoma cell sample
# 293 is_a FF:0000210 human sample
# 293 is_a FF:0000998 adult tissue sample
# 294 is_a FF:0000004 tissue sample
# 294 is_a FF:0000210 human sample
# 295 is_a FF:0000004 tissue sample
# 295 is_a FF:0000210 human sample
# 296 is_a EFO:0002091 biological replicate
# 296 is_a FF:0000210 human sample
# 296 is_a FF:0101967 cervical cancer cell line sample
# 297 is_a EFO:0002091 biological replicate
# 297 is_a FF:0000210 human sample
# 297 is_a FF:0101967 cervical cancer cell line sample
# 298 is_a EFO:0002091 biological replicate
# 298 is_a FF:0000210 human sample
# 298 is_a FF:0102842 cholangioma cell sample
# 299 is_a EFO:0002091 biological replicate
# 299 is_a FF:0000210 human sample
# 299 is_a FF:0102003 SW-1353 cell sample
# 300 is_a EFO:0002091 biological replicate
# 300 is_a FF:0000210 human sample
# 300 is_a FF:0100798 BeWo cell sample
# 301 is_a EFO:0002091 biological replicate
# 301 is_a FF:0000210 human sample
# 301 is_a FF:0101575 choriocarcinoma cell line sample
# 302 is_a EFO:0002091 biological replicate
# 302 is_a FF:0000210 human sample
# 302 is_a FF:0101575 choriocarcinoma cell line sample
# 303 is_a EFO:0002091 biological replicate
# 303 is_a FF:0000210 human sample
# 303 is_a FF:0103505 T-cell chronic lymphocytic leukemia cell sample
# 304 is_a EFO:0002091 biological replicate
# 304 is_a FF:0000210 human sample
# 304 is_a FF:0104137 KCL-22 cell sample
# 305 is_a EFO:0002091 biological replicate
# 305 is_a FF:0000210 human sample
# 305 is_a FF:0100740 myeloid leukemia cell line sample
# 306 is_a EFO:0002091 biological replicate
# 306 is_a FF:0000210 human sample
# 306 is_a FF:0100664 K-562 cell sample
# 307 is_a EFO:0002091 biological replicate
# 307 is_a FF:0000210 human sample
# 307 is_a FF:0100664 K-562 cell sample
# 308 is_a EFO:0002091 biological replicate
# 308 is_a FF:0000210 human sample
# 308 is_a FF:0100664 K-562 cell sample
# 309 is_a EFO:0002091 biological replicate
# 309 is_a FF:0000210 human sample
# 309 is_a FF:0100664 K-562 cell sample
# 310 is_a EFO:0002091 biological replicate
# 310 is_a FF:0000210 human sample
# 310 is_a FF:0100732 KU-812 cell sample
# 311 is_a EFO:0002091 biological replicate
# 311 is_a FF:0000210 human sample
# 311 is_a FF:0102787 clear cell adenocarcinoma cell sample
# 312 is_a EFO:0002091 biological replicate
# 312 is_a FF:0000210 human sample
# 312 is_a FF:0102787 clear cell adenocarcinoma cell sample
# 313 is_a EFO:0002091 biological replicate
# 313 is_a FF:0000210 human sample
# 313 is_a FF:0100195 CACO-2 cell sample
# 314 is_a EFO:0002091 biological replicate
# 314 is_a FF:0000210 human sample
# 314 is_a FF:0102047 Colo-320 cell sample
# 315 is_a EFO:0002091 biological replicate
# 315 is_a FF:0000041 common myeloid progenitor sample
# 315 is_a FF:0000210 human sample
# 316 is_a EFO:0002091 biological replicate
# 316 is_a FF:0000041 common myeloid progenitor sample
# 316 is_a FF:0000210 human sample
# 317 is_a EFO:0002091 biological replicate
# 317 is_a FF:0000210 human sample
# 317 is_a FF:0000625 experimental infection sample
# 317 is_a FF:0104053 umbilical cord blood sample
# 318 is_a EFO:0002091 biological replicate
# 318 is_a FF:0000210 human sample
# 318 is_a FF:0000625 experimental infection sample
# 318 is_a FF:0104053 umbilical cord blood sample
# 319 is_a EFO:0002091 biological replicate
# 319 is_a FF:0000210 human sample
# 319 is_a FF:0000343 control treatment sample
# 319 is_a FF:0104053 umbilical cord blood sample
# 320 is_a EFO:0002091 biological replicate
# 320 is_a FF:0000210 human sample
# 320 is_a FF:0102521 diffuse large B-cell lymphoma cell sample
# 321 is_a EFO:0002091 biological replicate
# 321 is_a FF:0000210 human sample
# 321 is_a FF:0100297 carcinoma cell line sample
# 321 is_a FF:0100794 pancreatic cancer cell line sample
# 322 is_a EFO:0002091 biological replicate
# 322 is_a FF:0000210 human sample
# 322 is_a FF:0100297 carcinoma cell line sample
# 322 is_a FF:0100794 pancreatic cancer cell line sample
# 323 is_a EFO:0002091 biological replicate
# 323 is_a FF:0000210 human sample
# 323 is_a FF:0100007 HEK-293 cell sample
# 324 is_a EFO:0002091 biological replicate
# 324 is_a FF:0000210 human sample
# 324 is_a FF:0100007 HEK-293 cell sample
# 325 is_a EFO:0002091 biological replicate
# 325 is_a FF:0000210 human sample
# 325 is_a FF:0100669 embryonic cell line sample
# 326 is_a EFO:0002091 biological replicate
# 326 is_a FF:0000210 human sample
# 326 is_a FF:0100669 embryonic cell line sample
# 327 is_a EFO:0002091 biological replicate
# 327 is_a FF:0000210 human sample
# 327 is_a FF:0100669 embryonic cell line sample
# 328 is_a EFO:0002091 biological replicate
# 328 is_a FF:0000210 human sample
# 328 is_a FF:0100669 embryonic cell line sample
# 329 is_a EFO:0002091 biological replicate
# 329 is_a FF:0000210 human sample
# 329 is_a FF:0100658 uterine adenocarcinoma cell sample
# 329 is_a FF:0101555 endometrial cancer cell line sample
# 330 is_a EFO:0002091 biological replicate
# 330 is_a FF:0000210 human sample
# 330 is_a FF:0100400 sarcoma cell line sample
# 330 is_a FF:0101555 endometrial cancer cell line sample
# 331 is_a EFO:0002091 biological replicate
# 331 is_a FF:0000210 human sample
# 331 is_a FF:0100658 uterine adenocarcinoma cell sample
# 331 is_a FF:0101555 endometrial cancer cell line sample
# 332 is_a EFO:0002091 biological replicate
# 332 is_a FF:0000210 human sample
# 332 is_a FF:0100017 A-431 cell sample
# 333 is_a EFO:0002091 biological replicate
# 333 is_a FF:0000210 human sample
# 333 is_a FF:0102024 squamous cell carcinoma cell line sample
# 333 is_a FF:0103109 CaSki cell sample
# 334 is_a EFO:0002091 biological replicate
# 334 is_a FF:0000210 human sample
# 334 is_a FF:0011289 epididymis- adult sample
# 335 is_a EFO:0002091 biological replicate
# 335 is_a FF:0000003 cell line sample
# 335 is_a FF:0000210 human sample
# 336 is_a EFO:0002091 biological replicate
# 336 is_a FF:0000003 cell line sample
# 336 is_a FF:0000210 human sample
# 337 is_a EFO:0002091 biological replicate
# 337 is_a FF:0000210 human sample
# 337 is_a FF:0101574 chondrosarcoma cell line sample
# 338 is_a EFO:0002091 biological replicate
# 338 is_a FF:0000210 human sample
# 338 is_a FF:0101282 HT-1080 cell sample
# 339 is_a EFO:0002091 biological replicate
# 339 is_a FF:0000210 human sample
# 339 is_a FF:0103766 giant cell tumor cell line sample
# 340 is_a EFO:0002091 biological replicate
# 340 is_a FF:0000210 human sample
# 340 is_a FF:0100297 carcinoma cell line sample
# 341 is_a EFO:0002091 biological replicate
# 341 is_a FF:0000210 human sample
# 341 is_a FF:0100297 carcinoma cell line sample
# 342 is_a FF:0200022 gamma delta positive T cells sample
# 343 is_a FF:0200022 gamma delta positive T cells sample
# 344 is_a EFO:0002091 biological replicate
# 344 is_a FF:0000210 human sample
# 344 is_a FF:0102384 MKN-1 cell sample
# 345 is_a EFO:0002091 biological replicate
# 345 is_a FF:0000210 human sample
# 345 is_a FF:0101225 MKN-45 cell sample
# 346 is_a EFO:0002091 biological replicate
# 346 is_a FF:0000210 human sample
# 346 is_a FF:0100787 gastric cancer cell line sample
# 347 is_a EFO:0002091 biological replicate
# 347 is_a FF:0000210 human sample
# 347 is_a FF:0100787 gastric cancer cell line sample
# 348 is_a EFO:0002091 biological replicate
# 348 is_a FF:0000210 human sample
# 348 is_a FF:0100297 carcinoma cell line sample
# 348 is_a FF:0101533 gastrointestinal cancer cell sample
# 349 is_a EFO:0002091 biological replicate
# 349 is_a FF:0000210 human sample
# 349 is_a FF:0102411 giant cell carcinoma cell line sample
# 350 is_a EFO:0002091 biological replicate
# 350 is_a FF:0000210 human sample
# 350 is_a FF:0102411 giant cell carcinoma cell line sample
# 351 is_a EFO:0002091 biological replicate
# 351 is_a FF:0000210 human sample
# 351 is_a FF:0100297 carcinoma cell line sample
# 352 is_a EFO:0002091 biological replicate
# 352 is_a FF:0000210 human sample
# 352 is_a FF:0100016 A-172 cell sample
# 353 is_a EFO:0002091 biological replicate
# 353 is_a FF:0000210 human sample
# 353 is_a FF:0100016 A-172 cell sample
# 354 is_a EFO:0002091 biological replicate
# 354 is_a FF:0000210 human sample
# 354 is_a FF:0101583 T-98G cell sample
# 355 is_a EFO:0002091 biological replicate
# 355 is_a FF:0000210 human sample
# 355 is_a FF:0100711 glioma cell line sample
# 356 is_a FF:0000004 tissue sample
# 356 is_a FF:0000210 human sample
# 357 is_a EFO:0002091 biological replicate
# 357 is_a FF:0000070 granulocyte macrophage progenitor cell sample
# 357 is_a FF:0000210 human sample
# 358 is_a EFO:0002091 biological replicate
# 358 is_a FF:0000070 granulocyte macrophage progenitor cell sample
# 358 is_a FF:0000210 human sample
# 359 is_a EFO:0002091 biological replicate
# 359 is_a FF:0000070 granulocyte macrophage progenitor cell sample
# 359 is_a FF:0000210 human sample
# 360 is_a EFO:0002091 biological replicate
# 360 is_a FF:0000210 human sample
# 360 is_a FF:0102285 granulosa cell line sample
# 361 is_a FF:0000210 human sample
# 361 is_a FF:0300101 hIPS sample
# 362 is_a FF:0000210 human sample
# 362 is_a FF:0300101 hIPS sample
# 363 is_a FF:0000210 human sample
# 363 is_a FF:0300101 hIPS sample
# 364 is_a FF:0000210 human sample
# 364 is_a FF:0300101 hIPS sample
# 365 is_a FF:0000210 human sample
# 365 is_a FF:0300101 hIPS sample
# 366 is_a FF:0000210 human sample
# 366 is_a FF:0300101 hIPS sample
# 367 is_a EFO:0002091 biological replicate
# 367 is_a FF:0000210 human sample
# 367 is_a FF:0101014 Mo-T cell sample
# 368 is_a EFO:0002091 biological replicate
# 368 is_a FF:0000210 human sample
# 368 is_a FF:0101533 gastrointestinal cancer cell sample
# 368 is_a FF:0103519 LI90 cell sample
# 369 is_a EFO:0002091 biological replicate
# 369 is_a FF:0000210 human sample
# 369 is_a FF:0101670 HuH-6 cell sample
# 370 is_a EFO:0002091 biological replicate
# 370 is_a FF:0000210 human sample
# 370 is_a FF:0100599 Hep-G2 cell sample
# 371 is_a EFO:0002091 biological replicate
# 371 is_a FF:0000210 human sample
# 371 is_a FF:0100599 Hep-G2 cell sample
# 372 is_a EFO:0002091 biological replicate
# 372 is_a FF:0000210 human sample
# 372 is_a FF:0100599 Hep-G2 cell sample
# 373 is_a EFO:0002091 biological replicate
# 373 is_a FF:0000210 human sample
# 373 is_a FF:0100578 hepatoma cell line sample
# 374 is_a EFO:0002091 biological replicate
# 374 is_a FF:0000210 human sample
# 374 is_a FF:0101524 WIL2-NS cell sample
# 375 is_a FF:0000004 tissue sample
# 375 is_a FF:0000210 human sample
# 376 is_a FF:0000210 human sample
# 376 is_a FF:0000380 0 days sample
# 376 is_a FF:0200003 iPS differentiation to neuron, control sample
# 377 is_a FF:0000210 human sample
# 377 is_a FF:0200003 iPS differentiation to neuron, control sample
# 378 is_a FF:0000210 human sample
# 378 is_a FF:0200003 iPS differentiation to neuron, control sample
# 379 is_a FF:0000210 human sample
# 379 is_a FF:0200003 iPS differentiation to neuron, control sample
# 380 is_a FF:0000210 human sample
# 380 is_a FF:0200003 iPS differentiation to neuron, control sample
# 381 is_a FF:0000210 human sample
# 381 is_a FF:0200003 iPS differentiation to neuron, control sample
# 382 is_a FF:0000210 human sample
# 382 is_a FF:0200003 iPS differentiation to neuron, control sample
# 383 is_a FF:0000210 human sample
# 383 is_a FF:0200003 iPS differentiation to neuron, control sample
# 384 is_a FF:0000210 human sample
# 384 is_a FF:0200003 iPS differentiation to neuron, control sample
# 385 is_a FF:0200003 iPS differentiation to neuron, control sample
# 386 is_a FF:0000210 human sample
# 386 is_a FF:0200003 iPS differentiation to neuron, control sample
# 387 is_a FF:0200003 iPS differentiation to neuron, control sample
# 388 is_a FF:0000210 human sample
# 388 is_a FF:0200003 iPS differentiation to neuron, control sample
# 389 is_a FF:0000210 human sample
# 389 is_a FF:0200003 iPS differentiation to neuron, control sample
# 390 is_a FF:0000210 human sample
# 390 is_a FF:0200003 iPS differentiation to neuron, control sample
# 391 is_a FF:0000210 human sample
# 391 is_a FF:0200003 iPS differentiation to neuron, control sample
# 392 is_a FF:0000210 human sample
# 392 is_a FF:0200003 iPS differentiation to neuron, control sample
# 393 is_a FF:0000210 human sample
# 393 is_a FF:0200003 iPS differentiation to neuron, control sample
# 394 is_a FF:0000210 human sample
# 394 is_a FF:0200003 iPS differentiation to neuron, control sample
# 395 is_a FF:0000210 human sample
# 395 is_a FF:0200003 iPS differentiation to neuron, control sample
# 396 is_a FF:0000210 human sample
# 396 is_a FF:0200003 iPS differentiation to neuron, control sample
# 397 is_a FF:0000210 human sample
# 397 is_a FF:0200003 iPS differentiation to neuron, control sample
# 398 is_a FF:0000210 human sample
# 398 is_a FF:0200003 iPS differentiation to neuron, control sample
# 399 is_a FF:0000210 human sample
# 399 is_a FF:0200003 iPS differentiation to neuron, control sample
# 400 is_a FF:0000210 human sample
# 400 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 401 is_a FF:0000210 human sample
# 401 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 402 is_a FF:0000210 human sample
# 402 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 403 is_a FF:0000210 human sample
# 403 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 404 is_a FF:0000210 human sample
# 404 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 405 is_a FF:0000210 human sample
# 405 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 406 is_a FF:0000210 human sample
# 406 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 407 is_a FF:0000210 human sample
# 407 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 408 is_a FF:0000210 human sample
# 408 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 409 is_a FF:0000210 human sample
# 409 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 410 is_a FF:0000210 human sample
# 410 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 411 is_a FF:0000210 human sample
# 411 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 412 is_a FF:0000210 human sample
# 412 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 413 is_a FF:0000210 human sample
# 413 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 414 is_a FF:0000210 human sample
# 414 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 415 is_a FF:0000210 human sample
# 415 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 416 is_a FF:0000210 human sample
# 416 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 417 is_a FF:0000210 human sample
# 417 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 418 is_a FF:0000210 human sample
# 418 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 419 is_a FF:0000210 human sample
# 419 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# 420 is_a FF:0000210 human sample
# 420 is_a FF:0200004 iPS differentiation to neuron, down-syndrome donor sample
# ...
# 444 is_a FF:0000210 human sample
# 445 is_a FF:0000004 tissue sample
# 445 is_a FF:0000210 human sample
# 446 is_a EFO:0002091 biological replicate
# 446 is_a FF:0000002 in vivo cell sample
# 447 is_a FF:0000004 tissue sample
# 447 is_a FF:0000210 human sample
# 448 is_a FF:0000004 tissue sample
# 448 is_a FF:0000210 human sample
# 449 is_a FF:0000004 tissue sample
# 449 is_a FF:0000210 human sample
# 450 is_a EFO:0002091 biological replicate
# 450 is_a FF:0000210 human sample
# 450 is_a FF:0101359 medulloblastoma cell line sample
# 451 is_a EFO:0002091 biological replicate
# 451 is_a FF:0000210 human sample
# 451 is_a FF:0101359 medulloblastoma cell line sample
# 452 is_a EFO:0002091 biological replicate
# 452 is_a FF:0000210 human sample
# 452 is_a FF:0100849 melanoma cell line sample
# 453 is_a EFO:0002091 biological replicate
# 453 is_a FF:0000210 human sample
# 453 is_a FF:0101584 G-361 cell sample
# 454 is_a EFO:0002091 biological replicate
# 454 is_a FF:0000210 human sample
# 454 is_a FF:0101120 epithelial cell line sample
# 454 is_a FF:0104398 meningioma cell line sample
# 455 is_a EFO:0002091 biological replicate
# 455 is_a FF:0000210 human sample
# 455 is_a FF:0100297 carcinoma cell line sample
# 456 is_a EFO:0002091 biological replicate
# 456 is_a FF:0000210 human sample
# 456 is_a FF:0100297 carcinoma cell line sample
# 457 is_a EFO:0002091 biological replicate
# 457 is_a FF:0000003 cell line sample
# 457 is_a FF:0000210 human sample
# 458 is_a EFO:0002091 biological replicate
# 458 is_a FF:0000210 human sample
# 458 is_a FF:0100669 embryonic cell line sample
# 459 is_a EFO:0002091 biological replicate
# 459 is_a FF:0000210 human sample
# 459 is_a FF:0102424 mesothelioma cell line sample
# 460 is_a EFO:0002091 biological replicate
# 460 is_a FF:0000210 human sample
# 460 is_a FF:0102424 mesothelioma cell line sample
# 461 is_a EFO:0002091 biological replicate
# 461 is_a FF:0000210 human sample
# 461 is_a FF:0102424 mesothelioma cell line sample
# 462 is_a EFO:0002091 biological replicate
# 462 is_a FF:0000210 human sample
# 462 is_a FF:0102424 mesothelioma cell line sample
# 463 is_a EFO:0002091 biological replicate
# 463 is_a FF:0000210 human sample
# 463 is_a FF:0102424 mesothelioma cell line sample
# 464 is_a EFO:0002091 biological replicate
# 464 is_a FF:0000210 human sample
# 464 is_a FF:0102424 mesothelioma cell line sample
# 465 is_a EFO:0002091 biological replicate
# 465 is_a FF:0000210 human sample
# 465 is_a FF:0102424 mesothelioma cell line sample
# 466 is_a EFO:0002091 biological replicate
# 466 is_a FF:0000210 human sample
# 466 is_a FF:0102424 mesothelioma cell line sample
# 467 is_a EFO:0002091 biological replicate
# 467 is_a FF:0000210 human sample
# 467 is_a FF:0102424 mesothelioma cell line sample
# 468 is_a EFO:0002091 biological replicate
# 468 is_a FF:0000210 human sample
# 468 is_a FF:0102424 mesothelioma cell line sample
# 469 is_a EFO:0002091 biological replicate
# 469 is_a FF:0000210 human sample
# 469 is_a FF:0102424 mesothelioma cell line sample
# 470 is_a EFO:0002091 biological replicate
# 470 is_a FF:0000210 human sample
# 470 is_a FF:0102424 mesothelioma cell line sample
# 470 is_a FF:0103764 NCI cell sample
# 471 is_a EFO:0002091 biological replicate
# 471 is_a FF:0000210 human sample
# 471 is_a FF:0102424 mesothelioma cell line sample
# 471 is_a FF:0103008 NCI-H226 cell sample
# 472 is_a EFO:0002091 biological replicate
# 472 is_a FF:0000210 human sample
# 472 is_a FF:0102424 mesothelioma cell line sample
# 472 is_a FF:0103764 NCI cell sample
# 473 is_a EFO:0002091 biological replicate
# 473 is_a FF:0000210 human sample
# 473 is_a FF:0102424 mesothelioma cell line sample
# 473 is_a FF:0103764 NCI cell sample
# 474 is_a EFO:0002091 biological replicate
# 474 is_a FF:0000210 human sample
# 474 is_a FF:0102424 mesothelioma cell line sample
# 475 is_a EFO:0002091 biological replicate
# 475 is_a FF:0000210 human sample
# 475 is_a FF:0102424 mesothelioma cell line sample
# 476 is_a EFO:0002091 biological replicate
# 476 is_a FF:0000003 cell line sample
# 476 is_a FF:0000210 human sample
# 477 is_a EFO:0002091 biological replicate
# 477 is_a FF:0000210 human sample
# 477 is_a FF:0102788 mucinous adenocarcinoma cell sample
# 478 is_a EFO:0002091 biological replicate
# 478 is_a FF:0000210 human sample
# 478 is_a FF:0104883 cystadenocarcinoma cell line sample
# 479 is_a EFO:0002091 biological replicate
# 479 is_a FF:0000210 human sample
# 479 is_a FF:0103212 T-lymphoma cell line sample
# 480 is_a EFO:0002091 biological replicate
# 480 is_a FF:0000003 cell line sample
# 480 is_a FF:0000210 human sample
# 481 is_a EFO:0002091 biological replicate
# 481 is_a FF:0000210 human sample
# 481 is_a FF:0100899 myeloma cell line sample
# 482 is_a EFO:0002091 biological replicate
# 482 is_a FF:0000210 human sample
# 482 is_a FF:0100460 fibrosarcoma cell line sample
# 483 is_a EFO:0002091 biological replicate
# 483 is_a FF:0000210 human sample
# 483 is_a FF:0100460 fibrosarcoma cell line sample
# 484 is_a EFO:0002091 biological replicate
# 484 is_a FF:0000210 human sample
# 484 is_a FF:0102989 CHP-134 cell sample
# 485 is_a EFO:0002091 biological replicate
# 485 is_a FF:0000210 human sample
# 485 is_a FF:0100932 neuroblastoma cell line sample
# 486 is_a EFO:0002091 biological replicate
# 486 is_a FF:0000210 human sample
# 486 is_a FF:0100932 neuroblastoma cell line sample
# 487 is_a EFO:0002091 biological replicate
# 487 is_a FF:0000210 human sample
# 487 is_a FF:0100932 neuroblastoma cell line sample
# 488 is_a EFO:0002091 biological replicate
# 488 is_a FF:0000210 human sample
# 488 is_a FF:0100669 embryonic cell line sample
# 489 is_a EFO:0002091 biological replicate
# 489 is_a FF:0000210 human sample
# 489 is_a FF:0100669 embryonic cell line sample
# 490 is_a EFO:0002091 biological replicate
# 490 is_a FF:0000210 human sample
# 490 is_a FF:0100669 embryonic cell line sample
# 491 is_a EFO:0002091 biological replicate
# 491 is_a FF:0000210 human sample
# 491 is_a FF:0102914 SK-N-MC cell sample
# 492 is_a EFO:0002091 biological replicate
# 492 is_a FF:0000210 human sample
# 492 is_a FF:0103046 neurofibroma cell sample
# 493 is_a EFO:0002091 biological replicate
# 493 is_a FF:0000003 cell line sample
# 493 is_a FF:0000210 human sample
# 494 is_a EFO:0002091 biological replicate
# 494 is_a FF:0000210 human sample
# 494 is_a FF:0100161 lung fibroblast cell line sample
# 494 is_a FF:0102553 non-small cell lung cancer cell line sample
# 494 is_a FF:0103764 NCI cell sample
# 495 is_a EFO:0002091 biological replicate
# 495 is_a FF:0000210 human sample
# 495 is_a FF:0100669 embryonic cell line sample
# 496 is_a EFO:0002091 biological replicate
# 496 is_a FF:0000210 human sample
# 496 is_a FF:0100003 intestinal cell line sample
# 496 is_a FF:0101120 epithelial cell line sample
# 497 is_a FF:0000004 tissue sample
# 497 is_a FF:0000210 human sample
# 498 is_a EFO:0002091 biological replicate
# 498 is_a FF:0000210 human sample
# 498 is_a FF:0102211 oral squamous cell carcinoma cell line sample
# 499 is_a EFO:0002091 biological replicate
# 499 is_a FF:0000210 human sample
# 499 is_a FF:0102211 oral squamous cell carcinoma cell line sample
# 500 is_a EFO:0002091 biological replicate
# 500 is_a FF:0000210 human sample
# 500 is_a FF:0102025 HSC-3 cell sample
# 501 is_a EFO:0002091 biological replicate
# 501 is_a FF:0000210 human sample
# 501 is_a FF:0103981 SAS cell sample
# 502 is_a EFO:0002091 biological replicate
# 502 is_a FF:0000210 human sample
# 502 is_a FF:0100969 osteoclastoma cell sample
# 503 is_a EFO:0002091 biological replicate
# 503 is_a FF:0000210 human sample
# 503 is_a FF:0100407 osteosarcoma cell line sample
# 504 is_a EFO:0002091 biological replicate
# 504 is_a FF:0000210 human sample
# 504 is_a FF:0100407 osteosarcoma cell line sample
# 505 is_a EFO:0002091 biological replicate
# 505 is_a FF:0000210 human sample
# 505 is_a FF:0100400 sarcoma cell line sample
# 506 is_a EFO:0002091 biological replicate
# 506 is_a FF:0000210 human sample
# 506 is_a FF:0103533 NOR-P1 cell sample
# 507 is_a EFO:0002091 biological replicate
# 507 is_a FF:0000210 human sample
# 507 is_a FF:0100167 adenocarcinoma cell line sample
# 507 is_a FF:0104965 8505C cell sample
# 508 is_a EFO:0002091 biological replicate
# 508 is_a FF:0000210 human sample
# 508 is_a FF:0100003 intestinal cell line sample
# 508 is_a FF:0100167 adenocarcinoma cell line sample
# 508 is_a FF:0101533 gastrointestinal cancer cell sample
# 509 is_a FF:0000004 tissue sample
# 509 is_a FF:0000210 human sample
# 510 is_a EFO:0002091 biological replicate
# 510 is_a FF:0000210 human sample
# 510 is_a FF:0100669 embryonic cell line sample
# 511 is_a EFO:0002091 biological replicate
# 511 is_a FF:0000210 human sample
# 511 is_a FF:0100834 Detroit 562 cell sample
# 512 is_a EFO:0002091 biological replicate
# 512 is_a FF:0000210 human sample
# 512 is_a FF:0102992 ARH-77 cell sample
# 513 is_a EFO:0002091 biological replicate
# 513 is_a FF:0000210 human sample
# 513 is_a FF:0103191 SNU-387 cell sample
# 514 is_a EFO:0002091 biological replicate
# 514 is_a FF:0000210 human sample
# 514 is_a FF:0101332 DU-145 cell sample
# 515 is_a EFO:0002091 biological replicate
# 515 is_a FF:0000210 human sample
# 515 is_a FF:0101061 PC-3 cell sample
# 516 is_a FF:0000004 tissue sample
# 516 is_a FF:0000210 human sample
# 517 is_a EFO:0002091 biological replicate
# 517 is_a FF:0000210 human sample
# 517 is_a FF:0101532 rectal cancer cell line sample
# 518 is_a EFO:0002091 biological replicate
# 518 is_a FF:0000210 human sample
# 518 is_a FF:0102403 OS-RC-2 cell sample
# 519 is_a EFO:0002091 biological replicate
# 519 is_a FF:0000210 human sample
# 519 is_a FF:0103732 TUHR-10TKB cell sample
# 520 is_a EFO:0002091 biological replicate
# 520 is_a FF:0000210 human sample
# 520 is_a FF:0102920 Y-79 cell sample
# 521 is_a EFO:0002091 biological replicate
# 521 is_a FF:0000210 human sample
# 521 is_a FF:0102267 rhabdomyosarcoma cell line sample
# 522 is_a EFO:0002091 biological replicate
# 522 is_a FF:0000210 human sample
# 522 is_a FF:0102267 rhabdomyosarcoma cell line sample
# 523 is_a EFO:0002091 biological replicate
# 523 is_a FF:0000003 cell line sample
# 523 is_a FF:0000210 human sample
# 524 is_a EFO:0002091 biological replicate
# 524 is_a FF:0000210 human sample
# 524 is_a FF:0103225 neurilemoma cell line sample
# 525 is_a EFO:0002091 biological replicate
# 525 is_a FF:0000210 human sample
# 525 is_a FF:0103225 neurilemoma cell line sample
# 526 is_a EFO:0002091 biological replicate
# 526 is_a FF:0000210 human sample
# 526 is_a FF:0103803 serous adenocarcinoma cell line sample
# 527 is_a EFO:0001746 development or differentiation design
# 527 is_a EFO:0002091 biological replicate
# 527 is_a FF:0000210 human sample
# 527 is_a FF:0000350 experimentally modified sample
# 527 is_a FF:0103803 serous adenocarcinoma cell line sample
# 528 is_a EFO:0002091 biological replicate
# 528 is_a FF:0000210 human sample
# 528 is_a FF:0103803 serous adenocarcinoma cell line sample
# 529 is_a EFO:0002091 biological replicate
# 529 is_a FF:0000210 human sample
# 529 is_a FF:0104511 serous cystadenocarcinoma cell sample
# 530 is_a EFO:0002091 biological replicate
# 530 is_a FF:0000210 human sample
# 530 is_a FF:0100167 adenocarcinoma cell line sample
# 530 is_a FF:0101092 KATO-III cell sample
# 531 is_a EFO:0002091 biological replicate
# 531 is_a FF:0000210 human sample
# 531 is_a FF:0100167 adenocarcinoma cell line sample
# 532 is_a EFO:0002091 biological replicate
# 532 is_a FF:0000210 human sample
# 532 is_a FF:0101967 cervical cancer cell line sample
# 533 is_a EFO:0002091 biological replicate
# 533 is_a FF:0000210 human sample
# 533 is_a FF:0100297 carcinoma cell line sample
# 533 is_a FF:0101533 gastrointestinal cancer cell sample
# 534 is_a EFO:0002091 biological replicate
# 534 is_a FF:0000210 human sample
# 534 is_a FF:0100189 small cell lung cancer cell sample
# 535 is_a EFO:0002091 biological replicate
# 535 is_a FF:0000210 human sample
# 535 is_a FF:0100189 small cell lung cancer cell sample
# 536 is_a EFO:0002091 biological replicate
# 536 is_a FF:0000210 human sample
# 536 is_a FF:0100189 small cell lung cancer cell sample
# 536 is_a FF:0103026 NCI-H82 cell sample
# 537 is_a EFO:0002091 biological replicate
# 537 is_a FF:0000210 human sample
# 537 is_a FF:0100189 small cell lung cancer cell sample
# 538 is_a EFO:0002091 biological replicate
# 538 is_a FF:0000210 human sample
# 538 is_a FF:0100297 carcinoma cell line sample
# 538 is_a FF:0101533 gastrointestinal cancer cell sample
# 539 is_a EFO:0002091 biological replicate
# 539 is_a FF:0000210 human sample
# 539 is_a FF:0101120 epithelial cell line sample
# 540 is_a FF:0000004 tissue sample
# 540 is_a FF:0000210 human sample
# 541 is_a EFO:0002091 biological replicate
# 541 is_a FF:0000210 human sample
# 541 is_a FF:0100400 sarcoma cell line sample
# 542 is_a EFO:0002091 biological replicate
# 542 is_a FF:0000210 human sample
# 542 is_a FF:0100104 lymphoma cell line sample
# 543 is_a EFO:0002091 biological replicate
# 543 is_a FF:0000210 human sample
# 543 is_a FF:0102024 squamous cell carcinoma cell line sample
# 544 is_a EFO:0002091 biological replicate
# 544 is_a FF:0000210 human sample
# 544 is_a FF:0102024 squamous cell carcinoma cell line sample
# 545 is_a EFO:0002091 biological replicate
# 545 is_a FF:0000210 human sample
# 545 is_a FF:0102024 squamous cell carcinoma cell line sample
# 546 is_a EFO:0002091 biological replicate
# 546 is_a FF:0000210 human sample
# 546 is_a FF:0103001 EBC-1 cell sample
# 547 is_a EFO:0002091 biological replicate
# 547 is_a FF:0000210 human sample
# 547 is_a FF:0101035 hematopoietic cell line sample
# 547 is_a FF:0102202 lung squamous cell carcinoma cell line sample
# 548 is_a EFO:0002091 biological replicate
# 548 is_a FF:0000210 human sample
# 548 is_a FF:0101035 hematopoietic cell line sample
# 548 is_a FF:0102202 lung squamous cell carcinoma cell line sample
# 549 is_a FF:0000004 tissue sample
# 549 is_a FF:0000210 human sample
# 550 is_a EFO:0002091 biological replicate
# 550 is_a FF:0000210 human sample
# 550 is_a FF:0100400 sarcoma cell line sample
# 550 is_a FF:0101120 epithelial cell line sample
# 551 is_a EFO:0002091 biological replicate
# 551 is_a FF:0000210 human sample
# 551 is_a FF:0100306 teratocarcinoma cell line sample
# 552 is_a EFO:0002091 biological replicate
# 552 is_a FF:0000210 human sample
# 552 is_a FF:0100306 teratocarcinoma cell line sample
# 553 is_a EFO:0002091 biological replicate
# 553 is_a FF:0000210 human sample
# 553 is_a FF:0100306 teratocarcinoma cell line sample
# 553 is_a FF:0101591 PA-1 cell sample
# 554 is_a EFO:0002091 biological replicate
# 554 is_a FF:0000210 human sample
# 554 is_a FF:0100306 teratocarcinoma cell line sample
# 554 is_a FF:0100669 embryonic cell line sample
# 554 is_a FF:0101560 testicular cancer cell line sample
# 555 is_a EFO:0002091 biological replicate
# 555 is_a FF:0000210 human sample
# 555 is_a FF:0100306 teratocarcinoma cell line sample
# 555 is_a FF:0100669 embryonic cell line sample
# 556 is_a EFO:0002091 biological replicate
# 556 is_a FF:0000210 human sample
# 556 is_a FF:0100306 teratocarcinoma cell line sample
# 556 is_a FF:0100669 embryonic cell line sample
# 557 is_a EFO:0002091 biological replicate
# 557 is_a FF:0000210 human sample
# 557 is_a FF:0100306 teratocarcinoma cell line sample
# 557 is_a FF:0100669 embryonic cell line sample
# 558 is_a FF:0000004 tissue sample
# 558 is_a FF:0000210 human sample
# 559 is_a EFO:0002091 biological replicate
# 559 is_a FF:0000210 human sample
# 559 is_a FF:0101455 thymic carcinoma cell sample
# 560 is_a EFO:0002091 biological replicate
# 560 is_a FF:0000210 human sample
# 560 is_a FF:0101610 thyroid cancer cell line sample
# 561 is_a EFO:0002091 biological replicate
# 561 is_a FF:0000210 human sample
# 561 is_a FF:0101610 thyroid cancer cell line sample
# 562 is_a EFO:0002091 biological replicate
# 562 is_a FF:0000210 human sample
# 562 is_a FF:0102869 transitional cell carcinoma cell line sample
# 563 is_a EFO:0002091 biological replicate
# 563 is_a FF:0000210 human sample
# 563 is_a FF:0103137 5637 cell sample
# 564 is_a EFO:0002091 biological replicate
# 564 is_a FF:0000210 human sample
# 564 is_a FF:0102869 transitional cell carcinoma cell line sample
# 565 is_a EFO:0002091 biological replicate
# 565 is_a FF:0000003 cell line sample
# 565 is_a FF:0000210 human sample
# 566 is_a EFO:0002091 biological replicate
# 566 is_a FF:0000210 human sample
# 566 is_a FF:0100167 adenocarcinoma cell line sample
# 566 is_a FF:0103493 SUIT-2 cell sample
# 567 is_a EFO:0002091 biological replicate
# 567 is_a FF:0000210 human sample
# 567 is_a FF:0101522 B-lymphocyte cell line sample

# %% [markdown]
# If we integrate the human subnetworks of these superclasses into our network, we get rid of most of the singletons.
# We do that by adding all meta nodes that are *between* the three 'root nodes' *cell line samples*, *tissue samples* and *in vivo cell samples* and the actual sample.
#
# We must not add nodes that are 'beyond' the 'root nodes', because otherwise we end up with a blown-up network including all terms down to the taxa.

# %%
graph = build_tree(obo_corr, HUMAN_SAMPLE[0], graph=nx.Graph())

# %%
for node in graph.nodes():
    if is_sample_id(node):
        add_superelements_to_graph(obo_corr, node, graph, delimiter_nodes=("FF:0000002", "FF:0000004", "FF:0000003"))

# %% [markdown]
# Fill unknown sample types with 'unknown' for better node coloring in cytoscape

# %%
col_vars.sample_type.fillna("unknown", inplace=True)

# %% [markdown]
# #### Export the new network for inspection in cytoscape

# %%
graph.remove_node(HUMAN_SAMPLE[0])
graph_ = annotate_graph(graph, col_vars)
graph_ = relabel_nodes(obo, graph_)

# %%
nx.write_graphml(graph_, "../networks/improve_network/human_samples_extended.graphml")

# %% [markdown]
# ## Singletons revisited (I)

# %% [markdown]
# We found that there is even another annotation "relationship"
# that we could use for improving our network hierarchy.

# %%
def is_singleton(graph, node_id):
    return True if len(graph[node_id]) == 0 else False

# %%
singletons_df = col_vars[col_vars.obo_id.isin([node for node in graph.nodes() if is_singleton(graph, node)])]
len(singletons_df)
# Out:
# 212

# %%
superclasses = []
for i, obo_id in enumerate(singletons_df.obo_id.values): 
    for tag, value, _ , comment in obo.term(obo_id).tags(): 
        if tag in [IS_A, RELATIONSHIP]: 
            superclasses.append((value, comment))
sorted([(superclasses.count(i), *i) for i in set(superclasses)])
# Out:
# [(1, 'FF:0000380', '0 days sample'),
#  (1, 'derives_from CL:0000134', 'mesenchymal cell'),
#  (1, 'derives_from UBERON:0000014', 'zone of skin'),
#  (1, 'derives_from UBERON:0000055', 'vessel'),
#  (1, 'derives_from UBERON:0001764', 'maxillary sinus'),
#  (1, 'derives_from UBERON:0001872', 'parietal lobe'),
#  (1, 'derives_from UBERON:0001873', 'caudate nucleus'),
#  (1, 'derives_from UBERON:0001874', 'putamen'),
#  (1, 'derives_from UBERON:0001875', 'globus pallidus'),
#  (1, 'derives_from UBERON:0001876', 'amygdala'),
#  (1, 'derives_from UBERON:0001896', 'medulla oblongata'),
#  (1, 'derives_from UBERON:0001897', 'dorsal plus ventral thalamus'),
#  (1, 'derives_from UBERON:0001954', "Ammon's horn"),
#  (1, 'derives_from UBERON:0002021', 'occipital lobe'),
#  (1, 'derives_from UBERON:0002037', 'cerebellum'),
#  (1, 'derives_from UBERON:0002038', 'substantia nigra'),
#  (1, 'derives_from UBERON:0002148', 'locus ceruleus'),
#  (1, 'derives_from UBERON:0002240', 'spinal cord'),
#  (1, 'derives_from UBERON:0002771', 'middle temporal gyrus'),
#  (1, 'derives_from UBERON:0003134', 'female reproductive organ'),
#  (1, 'derives_from UBERON:0007023', 'adult organism'),
#  (1, 'is_model_for DOID:1357', 'maxillary sinus cancer'),
#  (1, 'is_model_for DOID:225', 'syndrome'),
#  (1, 'is_model_for DOID:3149', 'keratoacanthoma'),
#  (1, 'is_model_for DOID:4', 'disease'),
#  (1, 'is_model_for DOID:4236', 'carcinosarcoma'),
#  (1, 'is_model_for DOID:74', 'hematopoietic system disease'),
#  (1, 'is_model_for DOID:9597', 'Krukenberg carcinoma'),
#  (2, 'is_model_for DOID:3307', 'teratoma'),
#  (2, 'is_model_for DOID:6193', 'epithelioid sarcoma'),
#  (3, 'derives_from UBERON:0002702', 'middle frontal gyrus'),
#  (4, 'EFO:0001461', 'control'),
#  (6, 'FF:0000357', '0 hr sample'),
#  (6, 'FF:0000375', '48 hr sample'),
#  (6, 'FF:0300101', 'hIPS sample'),
#  (6, 'is_model_for DOID:2841', 'asthma'),
#  (9, 'FF:0000363', '6 hr sample'),
#  (9, 'FF:0000367', '12 hr sample'),
#  (9, 'FF:0000373', '24 hr sample'),
#  (10, 'derives_from UBERON:0004225', 'respiratory system smooth muscle'),
#  (12, 'FF:0000003', 'cell line sample'),
#  (12, 'FF:0200008', '293SLAM rinderpest infection sample'),
#  (19, 'FF:0000004', 'tissue sample'),
#  (23,
#   'FF:0200004',
#   'iPS differentiation to neuron, down-syndrome donor sample'),
#  (25, 'FF:0200003', 'iPS differentiation to neuron, control sample'),
#  (27, 'FF:0200009', 'COBL-a rinderpest infection sample'),
#  (28, 'FF:0000002', 'in vivo cell sample'),
#  (37, 'EFO:0002091', 'biological replicate'),
#  (53, 'FF:0200006', 'myoblast differentiation to myotubes, control sample'),
#  (202, 'FF:0000210', 'human sample')]

# %% [markdown]
# there are still superclasses e.g. ` iPS differentiation to neuron, down-syndrome donor sample` or `rinderpest infection sample`. Why are these not captured?
#
# => these classes are not in a is_a relationship with any sample, but in a develops_from/derives_from relationship with GO terms.
# add these to network.

# %%
# !grep relationship ../data/ff-phase2-140729.obo | cut -d" " -f1,2 | sort -u
# Out:
# relationship: derives_from
# relationship: develops_from
# relationship: immediate_transformation_of
# relationship: is_model_for
# relationship: part_of
# relationship: treated_with

# %% [markdown]
# ### To capture most of it, we just add some manually

# %%
[(term.id, term.name) for term in obo_corr.parent_terms("FF:0200009")]
# Out:
# [('FF:0200010', 'rinderpest infection sample')]

# %%
[(term.id, term.name) for term in obo_corr.parent_terms("FF:0200008")]
# Out:
# [('FF:0200010', 'rinderpest infection sample')]

# %%
[(term.id, term.name) for term in obo_corr.parent_terms("FF:0200006")]
# Out:
# [('EFO:0001461', 'control'),
#  ('EFO:0001746', 'development or differentiation design'),
#  ('CL:0000056', 'myoblast'),
#  ('CL:0002372', 'myotube')]

# %%
[(term.id, term.name) for term in obo_corr.parent_terms("FF:0200003")]
# Out:
# [('EFO:0001461', 'control'),
#  ('FF:0200005', 'iPS differentiation to neuron sample')]

# %%
[(term.id, term.name) for term in obo_corr.parent_terms("FF:0200004")]
# Out:
# [('FF:0200005', 'iPS differentiation to neuron sample'),
#  ('DOID:14250', 'Down syndrome')]

# %%
graph2 = graph.copy()

# %%
delimiter_nodes = ["FF:0200009", "FF:0200006", "FF:0200005", "FF:0200008", "FF:0300101"]
for node in graph2.nodes():
    if is_sample_id(node):
        add_superelements_to_graph(obo_corr, node, graph2, delimiter_nodes=delimiter_nodes, inclusive=True)

# %% [markdown]
# ## Singletons revisited (II)
# However there are some where the proper superclass is really missing (lack of annotation).
# We will create these superclasses manually.

# %%
singletons_df = col_vars[col_vars.obo_id.isin([node for node in graph2.nodes() if is_singleton(graph2, node)])]
len(singletons_df)
# Out:
# 66

# %%
superclasses = []
for i, obo_id in enumerate(singletons_df.obo_id.values): 
    for tag, value, _ , comment in obo.term(obo_id).tags(): 
        if tag in [IS_A, RELATIONSHIP]: 
            superclasses.append((value, comment))
sorted([(superclasses.count(i), *i) for i in set(superclasses)])
# Out:
# [(1, 'derives_from CL:0000134', 'mesenchymal cell'),
#  (1, 'derives_from UBERON:0000014', 'zone of skin'),
#  (1, 'derives_from UBERON:0000055', 'vessel'),
#  (1, 'derives_from UBERON:0001764', 'maxillary sinus'),
#  (1, 'derives_from UBERON:0001872', 'parietal lobe'),
#  (1, 'derives_from UBERON:0001873', 'caudate nucleus'),
#  (1, 'derives_from UBERON:0001874', 'putamen'),
#  (1, 'derives_from UBERON:0001875', 'globus pallidus'),
#  (1, 'derives_from UBERON:0001876', 'amygdala'),
#  (1, 'derives_from UBERON:0001896', 'medulla oblongata'),
#  (1, 'derives_from UBERON:0001897', 'dorsal plus ventral thalamus'),
#  (1, 'derives_from UBERON:0001954', "Ammon's horn"),
#  (1, 'derives_from UBERON:0002021', 'occipital lobe'),
#  (1, 'derives_from UBERON:0002037', 'cerebellum'),
#  (1, 'derives_from UBERON:0002038', 'substantia nigra'),
#  (1, 'derives_from UBERON:0002148', 'locus ceruleus'),
#  (1, 'derives_from UBERON:0002240', 'spinal cord'),
#  (1, 'derives_from UBERON:0002771', 'middle temporal gyrus'),
#  (1, 'derives_from UBERON:0003134', 'female reproductive organ'),
#  (1, 'derives_from UBERON:0007023', 'adult organism'),
#  (1, 'is_model_for DOID:1357', 'maxillary sinus cancer'),
#  (1, 'is_model_for DOID:225', 'syndrome'),
#  (1, 'is_model_for DOID:3149', 'keratoacanthoma'),
#  (1, 'is_model_for DOID:4', 'disease'),
#  (1, 'is_model_for DOID:4236', 'carcinosarcoma'),
#  (1, 'is_model_for DOID:74', 'hematopoietic system disease'),
#  (1, 'is_model_for DOID:9597', 'Krukenberg carcinoma'),
#  (2, 'is_model_for DOID:3307', 'teratoma'),
#  (2, 'is_model_for DOID:6193', 'epithelioid sarcoma'),
#  (3, 'derives_from UBERON:0002702', 'middle frontal gyrus'),
#  (4, 'EFO:0001461', 'control'),
#  (6, 'is_model_for DOID:2841', 'asthma'),
#  (10, 'derives_from UBERON:0004225', 'respiratory system smooth muscle'),
#  (12, 'FF:0000003', 'cell line sample'),
#  (19, 'FF:0000004', 'tissue sample'),
#  (28, 'FF:0000002', 'in vivo cell sample'),
#  (37, 'EFO:0002091', 'biological replicate'),
#  (59, 'FF:0000210', 'human sample')]

# %%
try:
    graph2.remove_node(HUMAN_SAMPLE[0])
except nx.NetworkXError:
    pass
graph2_ = annotate_graph(graph2, col_vars)
graph2_ = relabel_nodes(obo, graph2_)

# %%
nx.write_graphml(graph2_, "../networks/improve_network/human_samples_extended.2.graphml")

# %% [markdown]
# * The CD4 cells: we can would need to classify them manually.
# * The smooth muscle cells: can be annotated using the derives_from ontology
# * `derives_from` could be intersting anyway

# %%
singletons_df.to_csv("../data/tmp/singletons.tsv", sep="\t", na_rep="na")

# %% [markdown]
# ### Create Meta Nodes manually
# There are some samples, where the proper meta-nodes are missing in the ontology (mainly T-Cell samples).
# Some of them are even annotated with a comment that the annotation is not complete.
#
# I will manually create these meta-nodes here and add them.

# %%
graph3 = graph2.copy()

# %%
def create_meta_node(name, obo, id_cntr, parent_ids=[]):
    new_id = "GS:{:04d}".format(id_cntr)
    try:
        term = OBOObject("Term", id=new_id, name=name)
        term.add_tag(SUBSET, UPDATE)
        for p_id in parent_ids:
            term.add_tag(IS_A, p_id, comment=obo.term(p_id).name)
        obo.add_object(term)
        return term
    except ValueError: 
        print("WARNING: Node with id already exists in ontology.")
        return obo.term(new_id)

# %%
cd4_1 = create_meta_node("human CD4-positiveCD25-positiveCD45RA-positive naive regulatory T cells sample", obo_corr, 1, [
                  HUMAN_SAMPLE[0], 
                  "FF:0000031" # CD 4 positive T cell sample
                 ]) 
terms = ["FF:11793-124C2", "FF:11796-124C5", "FF:11907-125F8"]
for term in terms: 
    obo_corr.term(term).add_tag(IS_A, cd4_1.id, comment=cd4_1.name)

# %%
cd4_2 = create_meta_node("human CD4-positiveCD25-positiveCD45RA- memory regulatory T cells sample", obo_corr, 2, [
                  HUMAN_SAMPLE[0], 
                  "FF:0000031" # CD 4 positive T cell sample
                 ]) 
terms = ["FF:11794-124C3", "FF:11916-125G8", "FF:11920-125H3", "FF:11797-124C6", "FF:11908-125F9"]
for term in terms: 
    obo_corr.term(term).add_tag(IS_A, cd4_2.id, comment=cd4_2.name)

# %%
cd4_3 = create_meta_node("human CD4-positiveCD25-CD45RA-positive naive conventional T cells sample", obo_corr, 3, [
                  HUMAN_SAMPLE[0], 
                  "FF:0000031" # CD 4 positive T cell sample
                 ]) 
terms = ["FF:11791-124B9", "FF:11913-125G5", "FF:11917-125G9", "FF:11784-124B2", "FF:11795-124C4", "FF:11906-125F7"]
for term in terms: 
    obo_corr.term(term).add_tag(IS_A, cd4_3.id, comment=cd4_3.name)

# %%
cd4_4 = create_meta_node("human CD4-positiveCD25-CD45RA- memory conventional T cells sample", obo_corr, 4, [
                  HUMAN_SAMPLE[0], 
                  "FF:0000031" # CD 4 positive T cell sample
                 ]) 
terms = ["FF:11792-124C1", "FF:11798-124C7", "FF:11909-125G1"]
for term in terms: 
    obo_corr.term(term).add_tag(IS_A, cd4_4.id, comment=cd4_4.name)

# %%
smc_1 = create_meta_node("human airway smooth muscle cell sample", obo_corr, 5, [
                  HUMAN_SAMPLE[0], 
                  "FF:0000167" # smooth muscle cell sample
                 ]) 
terms = ["FF:11960-126C7",
"FF:11961-126C8",
"FF:11962-126C9",
"FF:11963-126D1",
"FF:11964-126D2",
"FF:11965-126D3",
"FF:11966-126D4",
"FF:11967-126D5",
"FF:11968-126D6",
"FF:11969-126D7"]
for term in terms: 
    obo_corr.term(term).add_tag(IS_A, smc_1.id, comment=smc_1.name)

# %% [markdown]
# Replicates, where the annotation has been forgotten:

# %%
parent = obo_corr.term("FF:0010040") # human frontal lobe - adult sample
obo_corr.term("FF:10150-102I6").add_tag(IS_A, parent.id, comment=parent.name) # medial frontal gyrus, adult, donor10252

# %% [markdown]
# ### Build the network (from scratch, again)

# %%
graph3 = build_tree(obo_corr, HUMAN_SAMPLE[0], graph=nx.Graph())

# %%
delimiter_nodes = delimiter_nodes=("FF:0000002", "FF:0000004", "FF:0000003")
for node in graph3.nodes():
    if is_sample_id(node):
        add_superelements_to_graph(obo_corr, node, graph3, delimiter_nodes)

# %%
delimiter_nodes = ["FF:0200009", "FF:0200006", "FF:0200005", "FF:0200008", "FF:0300101"]
for node in graph3.nodes():
    if is_sample_id(node):
        add_superelements_to_graph(obo_corr, node, graph3, delimiter_nodes=delimiter_nodes, inclusive=True)

# %%
try:
    graph3.remove_node(HUMAN_SAMPLE[0])
except nx.NetworkXError:
    pass
graph3_ = annotate_graph(graph3, col_vars)
graph3_ = relabel_nodes(obo_corr, graph3_)

# %%
nx.write_graphml(graph3_, "../networks/improve_network/human_samples_extended.3.graphml")

# %%
obo_corr.write(open("../data/ff-phase2-140729.corr.obo", 'w'))

# %% [markdown]
# ## Conclusion
# We tried our very best to fix the bugs in the annotation, however it is unlikely that my analasis reveals and corrected all mistakes. So in a next step we have to do some computational outlier detection.
